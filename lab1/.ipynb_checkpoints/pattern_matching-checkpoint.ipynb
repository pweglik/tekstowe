# %% [markdown]
# # Text algorithms
# ## Pattern matching
# ### Author: Przemysław Węglik

# %% [markdown]
# ### Naive Algorithm

# %%
from collections import defaultdict
from typing import List, Dict, Tuple

# %%
Offsets = List[int]

def naive_algorithm(text: str, pattern: str) -> Offsets:
    n: int = len(text)
    m: int = len(pattern)
    
    offsets: Offsets = []
    
    # go through text letter by letter
    # +1 coz weird python syntax
    for i in range(n - m + 1):
        if text[i:(i + m)] == pattern:
            offsets.append(i)
            
    return offsets

# %%
naive_offsets: Offsets = []

with open("legal_paper", "r") as file:
    text: str = file.read()
    pattern: str = "art"
        
    naive_offsets = naive_algorithm(text, pattern)
    
len(naive_offsets), naive_offsets
# Out:
# (273,
#  [1156,
#   1505,
#   4692,
#   4734,
#   4879,
#   5082,
#   5148,
#   5949,
#   6039,
#   7266,
#   7511,
#   7781,
#   8044,
#   8299,
#   9104,
#   9959,
#   10022,
#   10224,
#   11122,
#   11207,
#   11618,
#   13194,
#   15284,
#   15358,
#   16092,
#   16261,
#   16406,
#   16547,
#   16616,
#   16840,
#   16856,
#   23637,
#   24061,
#   24152,
#   24586,
#   24683,
#   24780,
#   24931,
#   25530,
#   25689,
#   27001,
#   27288,
#   27479,
#   27542,
#   27592,
#   27857,
#   28373,
#   28558,
#   28766,
#   30964,
#   31021,
#   31096,
#   31362,
#   31811,
#   32609,
#   32968,
#   33053,
#   33268,
#   33595,
#   34651,
#   34737,
#   35511,
#   36155,
#   37143,
#   37543,
#   38451,
#   38595,
#   39056,
#   39210,
#   39436,
#   39568,
#   39980,
#   41152,
#   41829,
#   42028,
#   42198,
#   42371,
#   42504,
#   42718,
#   42896,
#   42941,
#   43447,
#   43555,
#   43787,
#   44590,
#   44653,
#   44953,
#   45010,
#   45293,
#   45401,
#   47319,
#   47422,
#   48785,
#   48820,
#   48906,
#   49052,
#   49259,
#   49316,
#   49488,
#   49559,
#   49915,
#   49979,
#   50102,
#   50160,
#   50702,
#   51050,
#   51179,
#   51966,
#   52071,
#   52272,
#   52552,
#   53008,
#   53032,
#   53211,
#   53788,
#   53931,
#   54078,
#   54137,
#   54770,
#   55075,
#   55279,
#   55465,
#   55807,
#   55991,
#   56827,
#   56911,
#   57164,
#   57549,
#   57800,
#   57932,
#   57989,
#   58280,
#   58378,
#   58874,
#   58966,
#   59395,
#   59523,
#   59949,
#   60296,
#   60549,
#   60794,
#   61262,
#   61770,
#   62463,
#   62610,
#   62663,
#   63504,
#   63698,
#   63789,
#   63869,
#   65075,
#   65114,
#   65176,
#   66024,
#   66330,
#   66982,
#   67056,
#   67578,
#   67695,
#   67720,
#   67852,
#   67926,
#   68226,
#   68854,
#   69046,
#   69172,
#   69249,
#   69604,
#   69697,
#   69794,
#   70109,
#   70512,
#   70664,
#   70698,
#   71561,
#   71705,
#   72106,
#   72314,
#   73115,
#   74253,
#   75346,
#   75470,
#   75486,
#   75493,
#   75717,
#   75803,
#   75871,
#   76247,
#   77030,
#   78047,
#   78558,
#   78872,
#   78936,
#   78970,
#   79091,
#   79270,
#   79341,
#   79410,
#   79448,
#   79582,
#   79822,
#   79884,
#   80848,
#   83234,
#   84578,
#   84828,
#   85834,
#   86793,
#   86819,
#   87093,
#   87174,
#   87359,
#   87399,
#   87640,
#   87707,
#   87947,
#   88033,
#   88073,
#   88136,
#   88391,
#   88665,
#   88940,
#   89047,
#   89316,
#   89325,
#   89341,
#   89361,
#   90167,
#   90218,
#   90572,
#   91682,
#   91795,
#   92916,
#   93366,
#   93426,
#   93561,
#   94603,
#   94808,
#   95981,
#   96120,
#   97285,
#   98770,
#   99825,
#   102953,
#   104141,
#   104723,
#   105767,
#   105973,
#   110186,
#   115010,
#   115163,
#   116109,
#   144052,
#   158607,
#   159478,
#   161581,
#   162788,
#   163969,
#   168897,
#   169074,
#   178453,
#   185631,
#   200530,
#   200628,
#   202696,
#   206794,
#   209181,
#   211819,
#   212319,
#   217444,
#   217891,
#   223168,
#   223252])

# %% [markdown]
# ### Finite state machine algorithm

# %%
Character = str
TransitionMatrix = Dict[int, Dict[str, int]]

def generate_transition_matrix(pattern: str) -> TransitionMatrix:
    m = len(pattern)
    transition_matrix = {i: defaultdict(int) for i in range(m + 1)}
    
    pattern_alphabet = set(pattern)
    
    for q in range(m + 1):
        for a in pattern_alphabet:
            # P_q.a - argument of suffix function
            prefix_with_letter = pattern[:q] + a
            prefix_length = q + 1

            # k goes from 1 to length of prefix
            for k in range(1, prefix_length + 1, 1):
                if pattern[:k] == prefix_with_letter[-k:]:
                    transition_matrix[q][a] = k
                    
    return transition_matrix
    
    
def finite_automata_algorithm(text: str, pattern: str, trans_mat = None) -> Offsets:
    
    m = len(pattern)
    state: int = 0
    offsets: Offsets = []
    
    if trans_mat is None:
        trans_mat: TransitionMatrix = generate_transition_matrix(pattern)
        
    for index, letter in enumerate(text):
        state = trans_mat[state][letter]
        if state == m:
            offsets.append(index + 1 - m)
        
    return offsets

# %%
fa_offsets: Offsets = []

with open("legal_paper", "r") as file:
    text: str = file.read()
    pattern: str = "art"
        
    fa_offsets = finite_automata_algorithm(text, pattern)
    
len(fa_offsets), fa_offsets
# Out:
# (273,
#  [1156,
#   1505,
#   4692,
#   4734,
#   4879,
#   5082,
#   5148,
#   5949,
#   6039,
#   7266,
#   7511,
#   7781,
#   8044,
#   8299,
#   9104,
#   9959,
#   10022,
#   10224,
#   11122,
#   11207,
#   11618,
#   13194,
#   15284,
#   15358,
#   16092,
#   16261,
#   16406,
#   16547,
#   16616,
#   16840,
#   16856,
#   23637,
#   24061,
#   24152,
#   24586,
#   24683,
#   24780,
#   24931,
#   25530,
#   25689,
#   27001,
#   27288,
#   27479,
#   27542,
#   27592,
#   27857,
#   28373,
#   28558,
#   28766,
#   30964,
#   31021,
#   31096,
#   31362,
#   31811,
#   32609,
#   32968,
#   33053,
#   33268,
#   33595,
#   34651,
#   34737,
#   35511,
#   36155,
#   37143,
#   37543,
#   38451,
#   38595,
#   39056,
#   39210,
#   39436,
#   39568,
#   39980,
#   41152,
#   41829,
#   42028,
#   42198,
#   42371,
#   42504,
#   42718,
#   42896,
#   42941,
#   43447,
#   43555,
#   43787,
#   44590,
#   44653,
#   44953,
#   45010,
#   45293,
#   45401,
#   47319,
#   47422,
#   48785,
#   48820,
#   48906,
#   49052,
#   49259,
#   49316,
#   49488,
#   49559,
#   49915,
#   49979,
#   50102,
#   50160,
#   50702,
#   51050,
#   51179,
#   51966,
#   52071,
#   52272,
#   52552,
#   53008,
#   53032,
#   53211,
#   53788,
#   53931,
#   54078,
#   54137,
#   54770,
#   55075,
#   55279,
#   55465,
#   55807,
#   55991,
#   56827,
#   56911,
#   57164,
#   57549,
#   57800,
#   57932,
#   57989,
#   58280,
#   58378,
#   58874,
#   58966,
#   59395,
#   59523,
#   59949,
#   60296,
#   60549,
#   60794,
#   61262,
#   61770,
#   62463,
#   62610,
#   62663,
#   63504,
#   63698,
#   63789,
#   63869,
#   65075,
#   65114,
#   65176,
#   66024,
#   66330,
#   66982,
#   67056,
#   67578,
#   67695,
#   67720,
#   67852,
#   67926,
#   68226,
#   68854,
#   69046,
#   69172,
#   69249,
#   69604,
#   69697,
#   69794,
#   70109,
#   70512,
#   70664,
#   70698,
#   71561,
#   71705,
#   72106,
#   72314,
#   73115,
#   74253,
#   75346,
#   75470,
#   75486,
#   75493,
#   75717,
#   75803,
#   75871,
#   76247,
#   77030,
#   78047,
#   78558,
#   78872,
#   78936,
#   78970,
#   79091,
#   79270,
#   79341,
#   79410,
#   79448,
#   79582,
#   79822,
#   79884,
#   80848,
#   83234,
#   84578,
#   84828,
#   85834,
#   86793,
#   86819,
#   87093,
#   87174,
#   87359,
#   87399,
#   87640,
#   87707,
#   87947,
#   88033,
#   88073,
#   88136,
#   88391,
#   88665,
#   88940,
#   89047,
#   89316,
#   89325,
#   89341,
#   89361,
#   90167,
#   90218,
#   90572,
#   91682,
#   91795,
#   92916,
#   93366,
#   93426,
#   93561,
#   94603,
#   94808,
#   95981,
#   96120,
#   97285,
#   98770,
#   99825,
#   102953,
#   104141,
#   104723,
#   105767,
#   105973,
#   110186,
#   115010,
#   115163,
#   116109,
#   144052,
#   158607,
#   159478,
#   161581,
#   162788,
#   163969,
#   168897,
#   169074,
#   178453,
#   185631,
#   200530,
#   200628,
#   202696,
#   206794,
#   209181,
#   211819,
#   212319,
#   217444,
#   217891,
#   223168,
#   223252])

# %% [markdown]
# ### Kunth-Morris-Pratt Algorithm

# %%
def prefix_function(pattern: str, q: int) -> int:
    for k in range(q - 1, -1, -1):
        if pattern[:k] == pattern[:q][-k:]:
            return k
    return 0
        

def kmp_algorithm(text: str, pattern: str, prefix_array = None) -> Offsets:

    m: int = len(pattern)
    
    if prefix_array is None:
        prefix_array: List[int] = [prefix_function(pattern, q) for q in range(1, m + 1)]
    offsets: Offsets = []

    j: int = 0
    for i in range(len(text)):
        while text[i] != pattern[j] and  j > 0:
            j = prefix_array[j - 1];
                
        if text[i] == pattern[j]:
            j += 1
            
        if j == m:
            offsets.append(i - j + 1)
            j = prefix_array[j - 1]
            
            
    return offsets

# %%
kmp_offsets: Offsets = []

with open("legal_paper", "r") as file:
    text: str = file.read()
    pattern: str = "art"
        
    kmp_offsets = kmp_algorithm(text, pattern)
    
len(kmp_offsets), kmp_offsets
# Out:
# (273,
#  [1156,
#   1505,
#   4692,
#   4734,
#   4879,
#   5082,
#   5148,
#   5949,
#   6039,
#   7266,
#   7511,
#   7781,
#   8044,
#   8299,
#   9104,
#   9959,
#   10022,
#   10224,
#   11122,
#   11207,
#   11618,
#   13194,
#   15284,
#   15358,
#   16092,
#   16261,
#   16406,
#   16547,
#   16616,
#   16840,
#   16856,
#   23637,
#   24061,
#   24152,
#   24586,
#   24683,
#   24780,
#   24931,
#   25530,
#   25689,
#   27001,
#   27288,
#   27479,
#   27542,
#   27592,
#   27857,
#   28373,
#   28558,
#   28766,
#   30964,
#   31021,
#   31096,
#   31362,
#   31811,
#   32609,
#   32968,
#   33053,
#   33268,
#   33595,
#   34651,
#   34737,
#   35511,
#   36155,
#   37143,
#   37543,
#   38451,
#   38595,
#   39056,
#   39210,
#   39436,
#   39568,
#   39980,
#   41152,
#   41829,
#   42028,
#   42198,
#   42371,
#   42504,
#   42718,
#   42896,
#   42941,
#   43447,
#   43555,
#   43787,
#   44590,
#   44653,
#   44953,
#   45010,
#   45293,
#   45401,
#   47319,
#   47422,
#   48785,
#   48820,
#   48906,
#   49052,
#   49259,
#   49316,
#   49488,
#   49559,
#   49915,
#   49979,
#   50102,
#   50160,
#   50702,
#   51050,
#   51179,
#   51966,
#   52071,
#   52272,
#   52552,
#   53008,
#   53032,
#   53211,
#   53788,
#   53931,
#   54078,
#   54137,
#   54770,
#   55075,
#   55279,
#   55465,
#   55807,
#   55991,
#   56827,
#   56911,
#   57164,
#   57549,
#   57800,
#   57932,
#   57989,
#   58280,
#   58378,
#   58874,
#   58966,
#   59395,
#   59523,
#   59949,
#   60296,
#   60549,
#   60794,
#   61262,
#   61770,
#   62463,
#   62610,
#   62663,
#   63504,
#   63698,
#   63789,
#   63869,
#   65075,
#   65114,
#   65176,
#   66024,
#   66330,
#   66982,
#   67056,
#   67578,
#   67695,
#   67720,
#   67852,
#   67926,
#   68226,
#   68854,
#   69046,
#   69172,
#   69249,
#   69604,
#   69697,
#   69794,
#   70109,
#   70512,
#   70664,
#   70698,
#   71561,
#   71705,
#   72106,
#   72314,
#   73115,
#   74253,
#   75346,
#   75470,
#   75486,
#   75493,
#   75717,
#   75803,
#   75871,
#   76247,
#   77030,
#   78047,
#   78558,
#   78872,
#   78936,
#   78970,
#   79091,
#   79270,
#   79341,
#   79410,
#   79448,
#   79582,
#   79822,
#   79884,
#   80848,
#   83234,
#   84578,
#   84828,
#   85834,
#   86793,
#   86819,
#   87093,
#   87174,
#   87359,
#   87399,
#   87640,
#   87707,
#   87947,
#   88033,
#   88073,
#   88136,
#   88391,
#   88665,
#   88940,
#   89047,
#   89316,
#   89325,
#   89341,
#   89361,
#   90167,
#   90218,
#   90572,
#   91682,
#   91795,
#   92916,
#   93366,
#   93426,
#   93561,
#   94603,
#   94808,
#   95981,
#   96120,
#   97285,
#   98770,
#   99825,
#   102953,
#   104141,
#   104723,
#   105767,
#   105973,
#   110186,
#   115010,
#   115163,
#   116109,
#   144052,
#   158607,
#   159478,
#   161581,
#   162788,
#   163969,
#   168897,
#   169074,
#   178453,
#   185631,
#   200530,
#   200628,
#   202696,
#   206794,
#   209181,
#   211819,
#   212319,
#   217444,
#   217891,
#   223168,
#   223252])

# %%
# proof of work - but not in a blockchain context
naive_offsets == fa_offsets, naive_offsets == kmp_offsets
# Out:
# (True, True)

# %% [markdown]
# ### Time benchamark function

# %%
import timeit

def time_benchmark_algorithms(
            text: str, 
            pattern: str, 
            N: int
            ) -> Tuple[float, float, float]:
    naive_timer = timeit.Timer(lambda: naive_algorithm(text, pattern))
    fa_timer = timeit.Timer(lambda: finite_automata_algorithm(text, pattern))
    kmp_timer = timeit.Timer(lambda: kmp_algorithm(text, pattern))
    
    
    
    return naive_timer.timeit(number=N), fa_timer.timeit(number=N), kmp_timer.timeit(number=N)
    

def time_benchmark_algorithms_no_pre(
            text: str, 
            pattern: str, 
            N: int
            ) -> Tuple[float, float, float]:
    
    trans_matrix = generate_transition_matrix(pattern)
    prefix_array = [prefix_function(pattern, q) for q in range(1, m + 1)]
        
    naive_timer = timeit.Timer(lambda: naive_algorithm(text, pattern))
    fa_timer = timeit.Timer(lambda: finite_automata_algorithm(text, pattern, trans_matrix))
    kmp_timer = timeit.Timer(lambda: kmp_algorithm(text, pattern))
    
    
    
    return naive_timer.timeit(number=N), fa_timer.timeit(number=N), kmp_timer.timeit(number=N)

# %% [markdown]
# ### Time benchmark for law paper

# %% [markdown]
# **Benchmark considering preprocessing time**

# %%
MIN = 10
MAX = 100
INTERVAL = 5

naive_times: List[float] = []
fa_times: List[float] = []
kmp_times: List[float] = []

with open("legal_paper", "r") as file:
    text: str = file.read()
    pattern: str = "art"
    
    for N in range(MIN, MAX + 1, INTERVAL):
        benchmarks = time_benchmark_algorithms(text, pattern, N)

        naive_times.append(benchmarks[0])
        fa_times.append(benchmarks[1])
        kmp_times.append(benchmarks[2])
        print(f'{N}', end = " ")
# Out:
# 10 done!
# 15 done!
# 20 done!
# 25 done!
# 30 done!
# 35 done!
# 40 done!
# 45 done!
# 50 done!
# 55 done!
# 60 done!
# 65 done!
# 70 done!
# 75 done!
# 80 done!
# 85 done!
# 90 done!
# 95 done!
# 100 done!

# %%
import matplotlib.pyplot as plt

X = [N for N in range(MIN, MAX + 1, INTERVAL)]

plt.plot(X, naive_times, label = 'Naive')
plt.plot(X, fa_times, label = 'FA')
plt.plot(X, kmp_times, label = 'KMP')
plt.legend()
plt.show()

# %% [markdown]
# **Benchamrks without preprocessing time**

# %%
MIN = 10
MAX = 100
INTERVAL = 5

naive_times_no_pre: List[float] = []
fa_times_no_pre: List[float] = []
kmp_times_no_pre: List[float] = []

with open("legal_paper", "r") as file:
    text: str = file.read()
    pattern: str = "art"
    
    for N in range(MIN, MAX + 1, INTERVAL):
        benchmarks = time_benchmark_algorithm(text, pattern, N)

        naive_times_no_pre.append(benchmarks[0])
        fa_times_no_pre.append(benchmarks[1])
        kmp_times_no_pre.append(benchmarks[2])
        print(f'{N} done!')
