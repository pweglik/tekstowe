# %% [markdown]
# # Levenshtein distance

# %%
import numpy as np

# %%
def delta(a: str, b: str):
    if a == b:
        return 0
    else:
        return 1

def edit_distance(x: str, y: str, delta):
    # create matrix
    edit_table = np.empty((len(x) + 1, len(y) + 1))
    string_table = np.empty((len(x) + 1, len(y) + 1))
    # fill first row and column
    edit_table[:, 0] = np.arange(len(x) + 1)
    edit_table[0, :] = np.arange(len(y) + 1)
        
    for i in range(len(x)):
        k = i + 1
        for j in range(len(y)):
            l = j + 1
            edit_table[k,l] = min(edit_table[k - 1, l] + 1, 
                                  edit_table[k, l - 1] + 1, 
                                  edit_table[k - 1 , l - 1] + delta(x[i], y[j]))
            
    return edit_table[len(x), len(y)], edit_table

# %%
def get_edits(x, y, edit_table):
    k = len(x)
    l = len(y)
    edits = []
    
    while k > 0 or l > 0:
        min_el = edit_table[k, l] + 1 # make sure it will always be bigger than surrundings
        if k >= 1 and l >= 1:
            min_el = min(min_el, edit_table[k - 1, l - 1])
        
        if l >= 1:
            min_el = min(min_el, edit_table[k, l - 1])
            
        if k >= 1:
            min_el = min(min_el, edit_table[k - 1, l])
        
        
        
        
        if edit_table[k - 1, l - 1] == min_el:
            k -= 1
            l -= 1
            if edit_table[k, l] + 1 == edit_table[k + 1, l + 1]:
                edits.append(f'{y[:l]}*{y[l]}*{x[k + 1:]} - substitute {x[k]} -> {y[l]}')
                
            
        elif edit_table[k, l - 1] == min_el:
            l -= 1
            edits.append(f'{y[:l]}*{y[l]}*{x[k:]} - insert {y[l]}')
            
        elif edit_table[k - 1, l] == min_el:
            k -= 1
            edits.append(f'{y[:l]}**{x[k + 1:]} - delete {x[k]}')
    
    return list(reversed(edits))

# %%
a = "los"
b = "kloc"
res, edit_table = edit_distance(a, b, delta)
res_edits = get_edits(a, b, edit_table)

print(f'Distance: {res}')
for edit in res_edits:
    print(edit)
# Out:
# Distance: 2.0
# *k*los - insert k
# klo*c* - substitute s -> c

# %%
a = "Łódź"
b = "Lodz"
res, edit_table = edit_distance(a, b, delta)
res_edits = get_edits(a, b, edit_table)

print(f'Distance: {res}')
for edit in res_edits:
    print(edit)
# Out:
# Distance: 3.0
# *L*ódź - substitute Ł -> L
# L*o*dź - substitute ó -> o
# Lod*z* - substitute ź -> z

# %%
a = "kwintesencja"
b = "quintessence"
res, edit_table = edit_distance(a, b, delta)
res_edits = get_edits(a, b, edit_table)

print(f'Distance: {res}')
for edit in res_edits:
    print(edit)
# Out:
# Distance: 5.0
# *q*wintesencja - substitute k -> q
# q*u*intesencja - substitute w -> u
# quintes*s*encja - insert s
# quintessenc**a - delete j
# quintessenc*e* - substitute a -> e

# %%
a = "ATGAATCTTACCGCCTCG"
b = "ATGAGGCTCTGGCCCCTG"
res, edit_table = edit_distance(a, b, delta)
res_edits = get_edits(a, b, edit_table)

print(f'Distance: {res}')
for edit in res_edits:
    print(edit)
# Out:
# Distance: 7.0
# ATGA*G*TCTTACCGCCTCG - substitute A -> G
# ATGAG*G*CTTACCGCCTCG - substitute T -> G
# ATGAGGCT*C*TACCGCCTCG - insert C
# ATGAGGCTCT*G*CCGCCTCG - substitute A -> G
# ATGAGGCTCTG*G*CGCCTCG - substitute C -> G
# ATGAGGCTCTGGC*C*CCTCG - substitute G -> C
# ATGAGGCTCTGGCCCCT**G - delete C

# %% [markdown]
# # Longest common subsequence

# %%
def lcs(x, y, edit_table, return_as_list = False):
    k = len(x)
    l = len(y)
    common_subsequence_len = 0
    lcs_len = 0
    lcs_k = -1 
    lcs_l = -1
    
    while k > 0 or l > 0:
        min_el = edit_table[k, l] + 1 # make sure it will always be bigger than surrundings
        if k >= 1 and l >= 1:
            min_el = min(min_el, edit_table[k - 1, l - 1])
        
        if l >= 1:
            min_el = min(min_el, edit_table[k, l - 1])
            
        if k >= 1:
            min_el = min(min_el, edit_table[k - 1, l])
        
        
        
        
        if edit_table[k - 1, l - 1] == min_el:
            k -= 1
            l -= 1
            if edit_table[k, l] == edit_table[k + 1, l + 1]:
                common_subsequence_len += 1
                if common_subsequence_len > lcs_len:
                    lcs_len = common_subsequence_len
                    lcs_k = k
                    lcs_l = l
            else:
                common_subsequence_len = 0
                
            
        elif edit_table[k, l - 1] == min_el:
            l -= 1
            common_subsequence_len = 0
            
        elif edit_table[k - 1, l] == min_el:
            k -= 1
            common_subsequence_len = 0
    
    if return_as_list:
        lcs = []
        for i in range(lcs_len):
             lcs.append(x[lcs_k + i])
    else:
        lcs = x[lcs_k]
        for i in range(1, lcs_len):
             lcs = lcs + x[lcs_k + i]
    
    return lcs

# %%
a = "los"
b = "kloc"
res, edit_table = edit_distance(a, b, delta)
lcs_res = lcs(a, b, edit_table)

print(f'LCS: {lcs_res}')
# Out:
# LCS: lo

# %%
a = "ATGAATCTTACCGCCTCG"
b = "ATGAGGCTCTGGCCCCTG"
res, edit_table = edit_distance(a, b, delta)
lcs_res = lcs(a, b, edit_table)

print(f'LCS: {lcs_res}')
# Out:
# LCS: ATGA

# %%
a = "kwintesencja"
b = "quintessence"
res, edit_table = edit_distance(a, b, delta)
lcs_res = lcs(a, b, edit_table)

print(f'LCS: {lcs_res}')
# Out:
# LCS: intes

# %%
string = "ala ma kota i psa i jest super"
a = string.split()
b = a[:3] + a[-2:]
res, edit_table = edit_distance(a, b, delta)
lcs_res = lcs(a, b, edit_table, return_as_list=True)

print(f'LCS: {lcs_res}')
# Out:
# LCS: ['ala', 'ma', 'kota']

# %% [markdown]
# # Custom 'diff' tool

# %%
from spacy.tokenizer import Tokenizer
from spacy.lang.pl import Polish
from copy import copy
nlp = Polish()
# Create a blank Tokenizer with just the English vocab
tokenizer = Tokenizer(nlp.vocab)
# Out:
# 2022-05-12 13:54:11.414319: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/przemek/projects/space_systems/ws_core/devel/lib:/opt/ros/noetic/lib:/opt/ros/noetic/lib/x86_64-linux-gnu
# 2022-05-12 13:54:11.414338: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# split text
with open("romeo-i-julia-700.txt", "r") as file:
    text = file.read()
    text = text.replace("\n", " \n ")
    tokens = text.split(' ')

# %%
# remove 3% of lines
edited_tokens = []

idx_to_del = np.random.randint(0, len(tokens) - 1, len(tokens)*3//100)
for idx, token in enumerate(tokens):
    if idx not in idx_to_del:
        edited_tokens.append(token)
    elif token == "\n":
        edited_tokens.append(token)

edited_text = " ".join(edited_tokens)

# %%
def diff(text, other_text):
    for idx, lines in enumerate(zip(text.split('\n'), other_text.split('\n'))):
        line, line_edited = lines

        res, edit_table = edit_distance(line.split(' '), line_edited.split(' '), delta)
        lcs_res = lcs(line.split(' '), line_edited.split(' '), edit_table, return_as_list=True)

        difference = set([el for el in line.split(' ') if el not in lcs_res]) | set([el for el in line_edited.split(' ') if el not in lcs_res])
        if len(difference) != 0:
            print(f'DIFF DETECTED IN LINE {idx}:\nline1:\n{line}\nline2:\n{line_edited}\ndiff: {difference}\n\n')
# Out:
# DIFF DETECTED IN LINE 16:
# line1:
#   * BENWOLIO — synowiec Montekiego
# line2:
#   * BENWOLIO — Montekiego
# diff: {'synowiec', 'Montekiego'}
#
#
# DIFF DETECTED IN LINE 21:
# line1:
#   * SAMSON, GRZEGORZ — słudzy Kapuleta
# line2:
#   SAMSON, GRZEGORZ — słudzy Kapuleta
# diff: {'*'}
#
#
# DIFF DETECTED IN LINE 30:
# line1:
#   * JULIA — córka Kapuletów
# line2:
#   * JULIA — Kapuletów
# diff: {'córka', 'Kapuletów'}
#
#
# DIFF DETECTED IN LINE 32:
# line1:
#   * Obywatele weroneńscy, różne osoby płci obojej, liczący się do przyjaciół obu domów, maski, straż wojskowa i inne osoby.
# line2:
#   * Obywatele weroneńscy, różne osoby płci obojej, liczący się do obu domów, maski, straż wojskowa i inne osoby.
# diff: {'wojskowa', 'obu', 'i', 'osoby.', 'maski,', 'przyjaciół', 'inne', 'domów,', 'straż'}
#
#
# DIFF DETECTED IN LINE 56:
# line1:
#  I jak się ojców nienawiść nie zmienia,
# line2:
#  I jak się ojców nie zmienia,
# diff: {'nie', 'nienawiść', 'zmienia,'}
#
#
# DIFF DETECTED IN LINE 75:
# line1:
#  SAMSON
# line2:
#
# diff: {'SAMSON'}
#
#
# DIFF DETECTED IN LINE 117:
# line1:
#  Te psy z domu Montekich rozruchać mię mogą tylko do stania na miejscu. Będę jak mur dla każdego mężczyzny i każdej kobiety z tego domu.
# line2:
#  Te psy z domu Montekich mię mogą tylko do stania na miejscu. Będę jak mur dla każdego mężczyzny i każdej kobiety z tego domu.
# diff: {'Te', 'psy', 'rozruchać', 'domu', 'Montekich'}
#
#
# DIFF DETECTED IN LINE 127:
# line1:
#  Prawda, dlatego to kobiety, jako najsłabsze, tulą się zawsze do muru. Ja też odtrącę od muru ludzi Montekich, a kobiety Montekich przyprę do muru.
# line2:
#  Prawda, dlatego to jako tulą się zawsze do muru. Ja też odtrącę od muru ludzi Montekich, a kobiety Montekich przyprę do muru.
# diff: {'jako', 'najsłabsze,', 'Prawda,', 'to', 'kobiety,', 'dlatego'}
#
#
# DIFF DETECTED IN LINE 140:
# line1:
#  GRZEGORZ
# line2:
#
# diff: {'GRZEGORZ'}
#
#
# DIFF DETECTED IN LINE 145:
# line1:
#  SAMSON
# line2:
#
# diff: {'SAMSON'}
#
#
# DIFF DETECTED IN LINE 154:
# line1:
#  / Wchodzą Abraham i Baltazar. /
# line2:
#  / Wchodzą i Baltazar. /
# diff: {'Wchodzą', 'Abraham'}
#
#
# DIFF DETECTED IN LINE 169:
# line1:
#  Nie bój się.
# line2:
#  bój się.
# diff: {'Nie'}
#
#
# DIFF DETECTED IN LINE 174:
# line1:
#  Ja bym się miał bać z twojej przyczyny!
# line2:
#  bym się miał bać twojej przyczyny!
# diff: {'', 'Ja', 'z', 'przyczyny!', 'twojej'}
#
#
# DIFF DETECTED IN LINE 194:
# line1:
#  Skrzywiłeś się na nas, mości panie?
# line2:
#  Skrzywiłeś się na nas, mości
# diff: {'panie?'}
#
#
# DIFF DETECTED IN LINE 211:
# line1:
#  Będziemy–ż mieli prawo za sobą, jak powiem: tak jest?
# line2:
#  Będziemy–ż prawo za sobą, powiem: tak jest?
# diff: {'za', 'jak', 'sobą,', 'prawo', 'Będziemy–ż', 'mieli'}
#
#
# DIFF DETECTED IN LINE 221:
# line1:
#  Nie, mości panie; nie skrzywiłem się na was, tylko skrzywiłem się tak sobie.
# line2:
#  Nie, mości panie; nie się na was, tylko skrzywiłem się sobie.
# diff: {'', 'nie', 'sobie.', 'Nie,', 'panie;', 'mości', 'tak'}
#
#
# DIFF DETECTED IN LINE 238:
# line1:
#  Jeżeli jej szukasz, to jestem na waścine usługi. Mój pan tak dobry jak i wasz.
# line2:
#  Jeżeli jej szukasz, to jestem na waścine Mój pan tak dobry jak i wasz.
# diff: {'jej', 'usługi.', 'Jeżeli', 'szukasz,', 'jestem', 'waścine', 'na', 'to'}
#
#
# DIFF DETECTED IN LINE 250:
# line1:
#  / Benwolio ukazuje się w głębi. /
# line2:
#  / Benwolio ukazuje w głębi. /
# diff: {'się', 'Benwolio', 'ukazuje'}
#
#
# DIFF DETECTED IN LINE 267:
# line1:
#  Kłamiesz.
# line2:
#
# diff: {'Kłamiesz.'}
#
#
# DIFF DETECTED IN LINE 272:
# line1:
#  Dobądźcie mieczów, jeśli macie serca. Grzegorzu, pamiętaj o swoim pchnięciu.
# line2:
#  Dobądźcie mieczów, jeśli macie serca. Grzegorzu, pamiętaj swoim pchnięciu.
# diff: {'swoim', 'pchnięciu.', 'o'}
#
#
# DIFF DETECTED IN LINE 279:
# line1:
#  / Rozdziela ich swoim mieczem. /
# line2:
#  / Rozdziela ich mieczem. /
# diff: {'mieczem.', 'swoim'}
#
#
# DIFF DETECTED IN LINE 344:
# line1:
#  Nie puszczę cię na krok, gdy wróg przed tobą.
# line2:
#  Nie puszczę cię na krok, gdy wróg tobą.
# diff: {'tobą.', 'przed'}
#
#
# DIFF DETECTED IN LINE 359:
# line1:
#  Wasz rozjątrzony książę postanawia.
# line2:
#  Wasz rozjątrzony postanawia.
# diff: {'postanawia.', 'książę'}
#
#
# DIFF DETECTED IN LINE 362:
# line1:
#  Trzykroć już spokój miasta zakłóciły,
# line2:
#  Trzykroć spokój miasta zakłóciły,
# diff: {'Trzykroć', 'już'}
#
#
# DIFF DETECTED IN LINE 368:
# line1:
#  Niechęci wasze przecinać. Jeżeli
# line2:
#  Niechęci przecinać. Jeżeli
# diff: {'Niechęci', 'wasze'}
#
#
# DIFF DETECTED IN LINE 376:
# line1:
#  Jeszcze raz wzywam wszystkich tu obecnych
# line2:
#  Jeszcze raz wzywam wszystkich tu
# diff: {'obecnych'}
#
#
# DIFF DETECTED IN LINE 388:
# line1:
#  BENWOLIO
# line2:
#
# diff: {'BENWOLIO'}
#
#
# DIFF DETECTED IN LINE 390:
# line1:
#  Nieprzyjaciela naszego pachołcy
# line2:
#  naszego pachołcy
# diff: {'Nieprzyjaciela'}
#
#
# DIFF DETECTED IN LINE 392:
# line1:
#  Dobyłem broni, aby ich rozdzielić:
# line2:
#  Dobyłem broni, ich rozdzielić:
# diff: {'broni,', 'Dobyłem', 'aby'}
#
#
# DIFF DETECTED IN LINE 393:
# line1:
#  Wtem wpadł szalony Tybalt z gołym mieczem,
# line2:
#  Wtem wpadł szalony Tybalt z gołym
# diff: {'mieczem,'}
#
#
# DIFF DETECTED IN LINE 398:
# line1:
#  Cięcia i pchnięcia zamieniali, zbiegł się
# line2:
#  Cięcia pchnięcia zamieniali, się
# diff: {'Cięcia', 'i', 'zamieniali,', 'zbiegł', 'pchnięcia'}
#
#
# DIFF DETECTED IN LINE 415:
# line1:
#  Ku południowi od naszego miasta.
# line2:
#  Ku południowi od miasta.
# diff: {'naszego', 'miasta.'}
#
#
# DIFF DETECTED IN LINE 418:
# line1:
#  Lecz on, spostrzegłszy mię, skrył się natychmiast
# line2:
#  Lecz on, spostrzegłszy mię, skrył się
# diff: {'natychmiast'}
#
#
# DIFF DETECTED IN LINE 421:
# line1:
#  Mierząc mym własnym (serce nasze bowiem
# line2:
#  mym własnym (serce nasze bowiem
# diff: {'Mierząc'}
#
#
# DIFF DETECTED IN LINE 433:
# line1:
#  Aliści ledwo na najdalszym wschodzie
# line2:
#  Aliści ledwo najdalszym wschodzie
# diff: {'na', 'Aliści', 'ledwo'}
#
#
# DIFF DETECTED IN LINE 463:
# line1:
#  Tak im jest wierny, tak zamknięty w sobie,
# line2:
#  Tak im wierny, tak zamknięty w sobie,
# diff: {'jest', 'im', 'Tak'}
#
#
# DIFF DETECTED IN LINE 505:
# line1:
#                          Jak nudnie
# line2:
#                       Jak nudnie
# diff: {'Jak', 'nudnie'}
#
#
# DIFF DETECTED IN LINE 512:
# line1:
#  Tak jest. Lecz cóż tak chwile twoje dłuży?
# line2:
#  jest. Lecz cóż tak chwile twoje dłuży?
# diff: {'Tak'}
#
#
# DIFF DETECTED IN LINE 527:
# line1:
#                          Brak jej.
# line2:
#                        Brak jej.
# diff: {'Brak', 'jej.'}
#
#
# DIFF DETECTED IN LINE 532:
# line1:
#                          Jak to? brak miłości?
# line2:
#                         Jak to? brak miłości?
# diff: {'Jak', 'brak', 'to?', 'miłości?'}
#
#
# DIFF DETECTED IN LINE 555:
# line1:
#  Coś narodzone z niczego! Pieszczoto
# line2:
#  Coś narodzone niczego! Pieszczoto
# diff: {'z', 'narodzone', 'Coś'}
#
#
# DIFF DETECTED IN LINE 559:
# line1:
#  Śnie bez snu! Taką to w sobie zawiłość,
# line2:
#  Śnie bez snu! Taką w sobie zawiłość,
# diff: {'zawiłość,', 'to', 'sobie', 'w'}
#
#
# DIFF DETECTED IN LINE 566:
# line1:
#                          Nie, płakałbym raczej.
# line2:
#                        Nie, płakałbym raczej.
# diff: {'płakałbym', 'Nie,', 'raczej.'}
#
#
# DIFF DETECTED IN LINE 582:
# line1:
#                          A więc strzała
# line2:
#                        A więc strzała
# diff: {'więc', 'A', 'strzała'}
#
#
# DIFF DETECTED IN LINE 601:
# line1:
#                          Zaczekaj! krzywdę byś mi sprawił,
# line2:
#                         Zaczekaj! krzywdę byś mi
# diff: {'Zaczekaj!', 'sprawił,', 'byś', 'krzywdę', 'mi'}
#
#
# DIFF DETECTED IN LINE 618:
# line1:
#                          Przestań mię dręczyć.
# line2:
#                         Przestań mię dręczyć.
# diff: {'dręczyć.', 'mię', 'Przestań'}
#
#
# DIFF DETECTED IN LINE 624:
# line1:
#                          Nie jęczyć,
# line2:
#                         Nie jęczyć,
# diff: {'Nie', 'jęczyć,'}
#
#
# DIFF DETECTED IN LINE 633:
# line1:
#  Dobre dla tego, kto jest w tak złym stanie?
# line2:
#  Dobre dla tego, kto jest tak złym stanie?
# diff: {'tak', 'złym', 'stanie?', 'w'}
#
#
# DIFF DETECTED IN LINE 645:
# line1:
#  Biegle celujesz. I ta, którą kocham,
# line2:
#  celujesz. I ta, którą kocham,
# diff: {'Biegle'}
#
#
# DIFF DETECTED IN LINE 651:
# line1:
#                          W piękny cel trafić najłatwiej.
# line2:
#                          piękny cel trafić najłatwiej.
# diff: {'W', 'cel', 'najłatwiej.', 'piękny', 'trafić'}
#
#
# DIFF DETECTED IN LINE 656:
# line1:
#  A właśnieś chybił. Niczym tu kołczany
# line2:
#  A chybił. Niczym tu kołczany
# diff: {'A', 'właśnieś'}
#
#
# DIFF DETECTED IN LINE 661:
# line1:
#  Odpiera szturmy spojrzeń napastniczych;
# line2:
#  Odpiera spojrzeń napastniczych;
# diff: {'szturmy', 'Odpiera'}
#
#
# DIFF DETECTED IN LINE 679:
# line1:
#  Zbyt mądrze piękna: stąd istnym jest głazem.
# line2:
#  Zbyt mądrze piękna: stąd istnym jest
# diff: {'głazem.'}
#
#
# DIFF DETECTED IN LINE 689:
# line1:
#  ROMEO
# line2:
#
# diff: {'ROMEO'}
#
#
# DIFF DETECTED IN LINE 697:
# line1:
#                          Dając oczom wolność
# line2:
#                        Dając oczom wolność
# diff: {'Dając', 'oczom', 'wolność'}
#
#
# DIFF DETECTED IN LINE 698:
# line1:
#  Rozpatrywania się w innych pięknościach.
# line2:
#  Rozpatrywania w innych pięknościach.
# diff: {'Rozpatrywania', 'się'}
